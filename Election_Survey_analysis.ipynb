# %% [markdown]
# # Election Survey Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
survey = pd.read_csv("Eletion_Survey_Dataset.csv")
survey.head()
# Out:
#    response_id collection_date urban_rural  education               income  \
# 0            1       5-24-2017       Rural  12th Pass  ₹ 30,000 - ₹ 50,000
# 1            2       5-24-2017       Rural   Graduate  ₹ 20,000 - ₹ 30,000
# 2            3       5-24-2017       Rural   Graduate   ₹ 5,000 - ₹ 10,000
# 3            4       5-24-2017       Urban   Graduate  ₹ 10,000 - ₹ 20,000
# 4            5       5-24-2017       Rural   Graduate  ₹ 50,000 - ₹ 80,000
#
#   Vote_Now     Past_Vote     CM_satisfaction    MLA_satisfaction age gender  \
# 0      BJP           BJP  Fully Dissatisfied  Fully Dissatisfied  26   Male
# 1     RLSP         JD(U)  Somewhat Satisfied  Fully Dissatisfied  34   Male
# 2   JAP(L)           BJP  Fully Dissatisfied  Somewhat Satisfied  25   Male
# 3      RJD           RJD  Fully Dissatisfied  Somewhat Satisfied  36   Male
# 4    JD(U)  Did not vote     Fully Satisfied     Fully Satisfied  22   Male
#
#    assembly_no category    weight
# 0          211      Gen  0.346969
# 1          189       BC  0.603419
# 2          191      Gen  0.673762
# 3          194      Gen  1.101298
# 4          176       BC  0.333505

# %%
survey.tail()
# Out:
#       response_id collection_date urban_rural               education  \
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age gender  assembly_no category    weight
# 6862  Fully Dissatisfied  25   Male          166      Gen  0.036329
# 6863  Fully Dissatisfied  30   Male          169       BC  0.252780
# 6864  Fully Dissatisfied  20   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23   Male          243      Gen  0.080137
# 6866     Fully Satisfied  33   Male          241      Gen  1.797518

# %%
survey.shape
# Out:
# (6867, 14)

# %%
survey.index
# Out:
# RangeIndex(start=0, stop=6867, step=1)

# %%
survey.dtypes
# Out:
# response_id           int64
# collection_date      object
# urban_rural          object
# education            object
# income               object
# Vote_Now             object
# Past_Vote            object
# CM_satisfaction      object
# MLA_satisfaction     object
# age                  object
# gender               object
# assembly_no           int64
# category             object
# weight              float64
# dtype: object

# %%
survey.columns
# Out:
# Index(['response_id', 'collection_date', 'urban_rural', 'education', 'income',
#        'Vote_Now', 'Past_Vote', 'CM_satisfaction', 'MLA_satisfaction', 'age',
#        'gender', 'assembly_no', 'category', 'weight'],
#       dtype='object')

# %%
survey.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6867 entries, 0 to 6866
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   response_id       6867 non-null   int64
#  1   collection_date   6867 non-null   object
#  2   urban_rural       6867 non-null   object
#  3   education         6867 non-null   object
#  4   income            6867 non-null   object
#  5   Vote_Now          6867 non-null   object
#  6   Past_Vote         6867 non-null   object
#  7   CM_satisfaction   6867 non-null   object
#  8   MLA_satisfaction  6867 non-null   object
#  9   age               6867 non-null   object
#  10  gender            6867 non-null   object
#  11  assembly_no       6867 non-null   int64
#  12  category          6867 non-null   object
#  13  weight            6867 non-null   float64
# dtypes: float64(1), int64(2), object(11)
# memory usage: 751.2+ KB

# %% [markdown]
# # Question 2 - How many samples were collected on each day?

# %%
survey['day'] = pd.to_datetime(survey['collection_date']).dt.day

# %%
survey
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age gender  assembly_no category    weight  day
# 0     Fully Dissatisfied  26   Male          211      Gen  0.346969   24
# 1     Fully Dissatisfied  34   Male          189       BC  0.603419   24
# 2     Somewhat Satisfied  25   Male          191      Gen  0.673762   24
# 3     Somewhat Satisfied  36   Male          194      Gen  1.101298   24
# 4        Fully Satisfied  22   Male          176       BC  0.333505   24
# ...                  ...  ..    ...          ...      ...       ...  ...
# 6862  Fully Dissatisfied  25   Male          166      Gen  0.036329    1
# 6863  Fully Dissatisfied  30   Male          169       BC  0.252780    1
# 6864  Fully Dissatisfied  20   Male          241      Gen  1.812926    1
# 6865  Somewhat Satisfied  23   Male          243      Gen  0.080137    1
# 6866     Fully Satisfied  33   Male          241      Gen  1.797518    1
#
# [6867 rows x 15 columns]

# %%
survey['day'].value_counts()
# Out:
# 24    1479
# 25     998
# 28     761
# 27     665
# 29     620
# 1      607
# 26     598
# 30     582
# 31     557
# Name: day, dtype: int64

# %% [markdown]
# # Question 3 - What proportion of the total respondents were aged less than 45?

# %%
survey[survey['age'] < '45']
# Out:
#       response_id collection_date urban_rural               education  \
# 0               1       5-24-2017       Rural               12th Pass
# 1               2       5-24-2017       Rural                Graduate
# 2               3       5-24-2017       Rural                Graduate
# 3               4       5-24-2017       Urban                Graduate
# 4               5       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6862         6863        6-1-2017       Rural               10th Pass
# 6863         6864        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
# 6866         6867        6-1-2017       Rural               10th Pass
#
#                    income Vote_Now     Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000      BJP           BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000     RLSP         JD(U)  Somewhat Satisfied
# 2      ₹ 5,000 - ₹ 10,000   JAP(L)           BJP  Fully Dissatisfied
# 3     ₹ 10,000 - ₹ 20,000      RJD           RJD  Fully Dissatisfied
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote     Fully Satisfied
# ...                   ...      ...           ...                 ...
# 6862    BPL/Below ₹ 5,000    JD(U)           BJP     Fully Satisfied
# 6863    BPL/Below ₹ 5,000      RJD           RJD  Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000   JAP(L)           RJD           Can’t say
# 6865  ₹ 10,000 - ₹ 20,000      BJP  Did not vote     Fully Satisfied
# 6866   ₹ 5,000 - ₹ 10,000   JAP(L)        JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age gender  assembly_no category    weight  day
# 0     Fully Dissatisfied  26   Male          211      Gen  0.346969   24
# 1     Fully Dissatisfied  34   Male          189       BC  0.603419   24
# 2     Somewhat Satisfied  25   Male          191      Gen  0.673762   24
# 3     Somewhat Satisfied  36   Male          194      Gen  1.101298   24
# 4        Fully Satisfied  22   Male          176       BC  0.333505   24
# ...                  ...  ..    ...          ...      ...       ...  ...
# 6862  Fully Dissatisfied  25   Male          166      Gen  0.036329    1
# 6863  Fully Dissatisfied  30   Male          169       BC  0.252780    1
# 6864  Fully Dissatisfied  20   Male          241      Gen  1.812926    1
# 6865  Somewhat Satisfied  23   Male          243      Gen  0.080137    1
# 6866     Fully Satisfied  33   Male          241      Gen  1.797518    1
#
# [6399 rows x 15 columns]

# %% [markdown]
# # Question 4 - Create a new column in the dataframe “age_group”. This column should contain the age group the respondent belongs to. The age groups are 18-25, 25-40, 40-55 and 55+. The dataframe should look like this after the column creation.

# %%
#data['age'].unique()
data['age'].replace({'24ko':'24'},inplace=True)
data['age'].unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '56', '50', '55', '54', '62', '60', '59', '47',
#        '61', '52', '66', '57', '67', '65', '71', '63', '64', '68', '69',
#        '99', '72', '75', '76'], dtype=object)

# %%
data['age_group'].unique()
data['age_group'].replace({'24ko':'24'},inplace=True)

# %%
data['age_group'].unique()
# Out:
# array(['26', '34', '25', '36', '22', '38', '23', '42', '51', '29', '24',
#        '30', '39', '37', '19', '44', '53', '32', '21', '18', '20', '27',
#        '48', '28', '45', '74', '35', '31', '70', '40', '49', '46', '43',
#        '41', '33', '58', '56', '50', '55', '54', '62', '60', '59', '47',
#        '61', '52', '66', '57', '67', '65', '71', '63', '64', '68', '69',
#        '99', '72', '75', '76'], dtype=object)

# %%
data1 =data[(data['age_group'] > '18') & (data['age_group'] < '25')]

# %%
data1['age_group'].unique()
# Out:
# array(['22', '23', '24', '19', '21', '20'], dtype=object)

# %%
data1['age_group'] = '18-25'
# Out:
# C:\Users\aslam\AppData\Local\Temp\ipykernel_10444\2139180286.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['age_group'] = '18-25'

# %%
data1
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6858         6859        6-1-2017       Rural                Graduate
# 6859         6860        6-1-2017       Urban       Post - Graduation
# 6861         6862        6-1-2017       Rural                Graduate
# 6864         6865        6-1-2017       Urban                Graduate
# 6865         6866        6-1-2017       Rural  Professional Education
#
#                    income    Vote_Now     Past_Vote        CM_satisfaction  \
# 4     ₹ 50,000 - ₹ 80,000       JD(U)  Did not vote        Fully Satisfied
# 8       BPL/Below ₹ 5,000         BJP           BJP        Fully Satisfied
# 14     ₹ 1,50,000 & above         BJP           BJP        Fully Satisfied
# 16      BPL/Below ₹ 5,000         RJD           RJD     Fully Dissatisfied
# 18    ₹ 30,000 - ₹ 50,000      JAP(L)         JD(U)  Somewhat Dissatisfied
# ...                   ...         ...           ...                    ...
# 6858  ₹ 10,000 - ₹ 20,000         RJD           RJD     Fully Dissatisfied
# 6859   ₹ 5,000 - ₹ 10,000  Left Front  Did not vote     Fully Dissatisfied
# 6861    BPL/Below ₹ 5,000         BJP           BJP     Fully Dissatisfied
# 6864   ₹ 5,000 - ₹ 10,000      JAP(L)           RJD              Can’t say
# 6865  ₹ 10,000 - ₹ 20,000         BJP  Did not vote        Fully Satisfied
#
#         MLA_satisfaction age age_group gender  assembly_no category    weight  \
# 4        Fully Satisfied  22     18-25   Male          176       BC  0.333505
# 8     Fully Dissatisfied  23     18-25   Male          181      Gen  0.226477
# 14    Fully Dissatisfied  24     18-25   Male          199      Gen  0.226477
# 16    Somewhat Satisfied  24     18-25   Male          194       BC  0.769738
# 18    Fully Dissatisfied  23     18-25   Male          188       BC  0.040519
# ...                  ...  ..       ...    ...          ...      ...       ...
# 6858     Fully Satisfied  24     18-25   Male          241      Gen  1.812926
# 6859  Somewhat Satisfied  21     18-25   Male          146      EBC  1.558234
# 6861  Somewhat Satisfied  22     18-25   Male          166      Gen  0.080137
# 6864  Fully Dissatisfied  20     18-25   Male          241      Gen  1.812926
# 6865  Somewhat Satisfied  23     18-25   Male          243      Gen  0.080137
#
#       day
# 4      24
# 8      24
# 14     24
# 16     24
# 18     24
# ...   ...
# 6858    1
# 6859    1
# 6861    1
# 6864    1
# 6865    1
#
# [1969 rows x 16 columns]

# %%
data2 =data[(data['age_group'] > '25') & (data['age_group'] < '40')]

# %%
data2['age_group'] = '25-40'
# Out:
# C:\Users\aslam\AppData\Local\Temp\ipykernel_10444\1359659790.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2['age_group'] = '25-40'

# %%
data2
# Out:
#       response_id collection_date urban_rural          education  \
# 0               1       5-24-2017       Rural          12th Pass
# 1               2       5-24-2017       Rural           Graduate
# 3               4       5-24-2017       Urban           Graduate
# 5               6       5-24-2017       Urban           Graduate
# 6               7       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6852         6853        6-1-2017       Rural           Graduate
# 6854         6855        6-1-2017       Rural  Post - Graduation
# 6855         6856        6-1-2017       Rural          12th Pass
# 6863         6864        6-1-2017       Rural           Graduate
# 6866         6867        6-1-2017       Rural          10th Pass
#
#                    income   Vote_Now Past_Vote     CM_satisfaction  \
# 0     ₹ 30,000 - ₹ 50,000        BJP       BJP  Fully Dissatisfied
# 1     ₹ 20,000 - ₹ 30,000       RLSP     JD(U)  Somewhat Satisfied
# 3     ₹ 10,000 - ₹ 20,000        RJD       RJD  Fully Dissatisfied
# 5     ₹ 20,000 - ₹ 30,000     Others       BJP  Somewhat Satisfied
# 6       BPL/Below ₹ 5,000        RJD       BJP  Fully Dissatisfied
# ...                   ...        ...       ...                 ...
# 6852  ₹ 10,000 - ₹ 20,000  Undecided       BJP     Fully Satisfied
# 6854   ₹ 5,000 - ₹ 10,000        RJD       BJP  Fully Dissatisfied
# 6855   ₹ 5,000 - ₹ 10,000       NOTA     JD(U)  Fully Dissatisfied
# 6863    BPL/Below ₹ 5,000        RJD       RJD  Fully Dissatisfied
# 6866   ₹ 5,000 - ₹ 10,000     JAP(L)    JAP(L)     Fully Satisfied
#
#         MLA_satisfaction age age_group gender  assembly_no category    weight  \
# 0     Fully Dissatisfied  26     25-40   Male          211      Gen  0.346969
# 1     Fully Dissatisfied  34     25-40   Male          189       BC  0.603419
# 3     Somewhat Satisfied  36     25-40   Male          194      Gen  1.101298
# 5     Fully Dissatisfied  38     25-40   Male          178      Gen  0.382603
# 6     Fully Dissatisfied  34     25-40   Male          172       BC  0.521283
# ...                  ...  ..       ...    ...          ...      ...       ...
# 6852     Fully Satisfied  28     25-40   Male          149       SC  0.983441
# 6854  Fully Dissatisfied  37     25-40   Male          143      Gen  0.085030
# 6855  Fully Dissatisfied  30     25-40   Male          241      EBC  0.174156
# 6863  Fully Dissatisfied  30     25-40   Male          169       BC  0.252780
# 6866     Fully Satisfied  33     25-40   Male          241      Gen  1.797518
#
#       day
# 0      24
# 1      24
# 3      24
# 5      24
# 6      24
# ...   ...
# 6852    1
# 6854    1
# 6855    1
# 6863    1
# 6866    1
#
# [3246 rows x 16 columns]

# %%
data3 =data[(data['age_group'] > '40') & (data['age_group'] < '55')]

# %%
data3['age_group'] ='40-55'
# Out:
# C:\Users\aslam\AppData\Local\Temp\ipykernel_10444\983973614.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data3['age_group'] ='40-55'

# %%
data3
# Out:
#       response_id collection_date urban_rural          education  \
# 11             12       5-24-2017       Urban           Graduate
# 12             13       5-24-2017       Urban  Post - Graduation
# 28             29       5-24-2017       Rural           Graduate
# 30             31       5-24-2017       Urban           Graduate
# 33             34       5-24-2017       Urban           Graduate
# ...           ...             ...         ...                ...
# 6810         6811        6-1-2017       Rural          12th Pass
# 6812         6813        6-1-2017       Rural          10th Pass
# 6829         6830        6-1-2017       Urban           Graduate
# 6840         6841        6-1-2017       Rural           Graduate
# 6856         6857        6-1-2017       Rural  Post - Graduation
#
#                    income   Vote_Now Past_Vote        CM_satisfaction  \
# 11    ₹ 10,000 - ₹ 20,000        LJP     JD(U)     Somewhat Satisfied
# 12     ₹ 5,000 - ₹ 10,000  Undecided     JD(U)  Somewhat Dissatisfied
# 28    ₹ 20,000 - ₹ 30,000      JD(U)       BJP        Fully Satisfied
# 30    ₹ 30,000 - ₹ 50,000       NOTA      NOTA     Fully Dissatisfied
# 33    ₹ 50,000 - ₹ 80,000        BJP       BJP        Fully Satisfied
# ...                   ...        ...       ...                    ...
# 6810   ₹ 1,50,000 & above        RJD       RJD     Somewhat Satisfied
# 6812   ₹ 5,000 - ₹ 10,000        BJP       RJD     Somewhat Satisfied
# 6829  ₹ 20,000 - ₹ 30,000      JD(U)     JD(U)        Fully Satisfied
# 6840   ₹ 1,50,000 & above       NOTA       BJP     Fully Dissatisfied
# 6856  ₹ 50,000 - ₹ 80,000        RJD     JD(U)     Somewhat Satisfied
#
#            MLA_satisfaction age age_group gender  assembly_no category  \
# 11       Fully Dissatisfied  42     40-55   Male          183       BC
# 12    Somewhat Dissatisfied  51     40-55   Male          183       SC
# 28          Fully Satisfied  44     40-55   Male          205       BC
# 30       Fully Dissatisfied  44     40-55   Male          183      Gen
# 33    Somewhat Dissatisfied  53     40-55   Male          188      Gen
# ...                     ...  ..       ...    ...          ...      ...
# 6810     Fully Dissatisfied  52     40-55   Male          150      Gen
# 6812        Fully Satisfied  45     40-55   Male          142      Gen
# 6829     Somewhat Satisfied  48     40-55   Male          146      EBC
# 6840     Somewhat Satisfied  45     40-55   Male          241       BC
# 6856  Somewhat Dissatisfied  45     40-55   Male          150       BC
#
#          weight  day
# 11     2.824391   24
# 12    20.558759   24
# 28     1.337935   24
# 30     1.344773   24
# 33     1.936195   24
# ...         ...  ...
# 6810   2.112264    1
# 6812   0.710519    1
# 6829   6.328899    1
# 6840   1.425852    1
# 6856   2.112264    1
#
# [624 rows x 16 columns]

# %%
data4 = data[data['age_group'] > '55']

# %%
data4['age_group'] = '55+'
# Out:
# C:\Users\aslam\AppData\Local\Temp\ipykernel_10444\2931846356.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data4['age_group'] = '55+'

# %%
data4
# Out:
#       response_id collection_date urban_rural               education  \
# 69             70       5-24-2017       Rural                Graduate
# 74             75       5-24-2017       Urban                Graduate
# 121           122       5-24-2017       Rural                Graduate
# 126           127       5-24-2017       Urban                Graduate
# 277           278       5-24-2017       Urban       Post - Graduation
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                      income Vote_Now     Past_Vote        CM_satisfaction  \
# 69      ₹ 30,000 - ₹ 50,000      RJD           INC     Fully Dissatisfied
# 74      ₹ 30,000 - ₹ 50,000      BJP           BJP  Somewhat Dissatisfied
# 121     ₹ 20,000 - ₹ 30,000     NOTA  Did not vote     Somewhat Satisfied
# 126   ₹ 80,000 - ₹ 1,50,000     NOTA           BJP     Fully Dissatisfied
# 277     ₹ 30,000 - ₹ 50,000      BJP           BJP     Somewhat Satisfied
# ...                     ...      ...           ...                    ...
# 6579    ₹ 10,000 - ₹ 20,000      RJD         JD(U)     Fully Dissatisfied
# 6702    ₹ 10,000 - ₹ 20,000      BJP           BJP  Somewhat Dissatisfied
# 6720    ₹ 10,000 - ₹ 20,000      BJP           BJP     Somewhat Satisfied
# 6787    ₹ 20,000 - ₹ 30,000    JD(U)           BJP        Fully Satisfied
# 6851    ₹ 30,000 - ₹ 50,000      BJP           BJP        Fully Satisfied
#
#            MLA_satisfaction age age_group gender  assembly_no category  \
# 69          Fully Satisfied  74       55+   Male          192       ST
# 74       Somewhat Satisfied  70       55+   Male          183       BC
# 121      Fully Dissatisfied  58       55+   Male          187      Gen
# 126      Fully Dissatisfied  56       55+   Male          183      Gen
# 277      Somewhat Satisfied  58       55+   Male          186      Gen
# ...                     ...  ..       ...    ...          ...      ...
# 6579     Fully Dissatisfied  67       55+   Male          141       SC
# 6702     Fully Dissatisfied  68       55+   Male          146      Gen
# 6720        Fully Satisfied  76       55+   Male          168      Gen
# 6787        Fully Satisfied  60       55+   Male          144       SC
# 6851  Somewhat Dissatisfied  66       55+   Male          165      Gen
#
#         weight  day
# 69    1.805903   24
# 74    0.343147   24
# 121   2.092567   24
# 126   2.092567   24
# 277   1.917992   24
# ...        ...  ...
# 6579  5.308107   29
# 6702  0.710519   31
# 6720  1.535906   31
# 6787  4.741094    1
# 6851  0.300990    1
#
# [108 rows x 16 columns]

# %%
data = pd.concat([data1,data2,data3,data4])

# %%
data
# Out:
#       response_id collection_date urban_rural               education  \
# 4               5       5-24-2017       Rural                Graduate
# 8               9       5-24-2017       Urban               12th Pass
# 14             15       5-24-2017       Rural                Graduate
# 16             17       5-24-2017       Rural       Post - Graduation
# 18             19       5-24-2017       Rural                Graduate
# ...           ...             ...         ...                     ...
# 6579         6580       5-29-2017       Rural                Graduate
# 6702         6703       5-31-2017       Urban  Professional Education
# 6720         6721       5-31-2017       Rural                Graduate
# 6787         6788        6-1-2017       Rural               10th Pass
# 6851         6852        6-1-2017       Urban                Graduate
#
#                    income Vote_Now     Past_Vote        CM_satisfaction  \
# 4     ₹ 50,000 - ₹ 80,000    JD(U)  Did not vote        Fully Satisfied
# 8       BPL/Below ₹ 5,000      BJP           BJP        Fully Satisfied
# 14     ₹ 1,50,000 & above      BJP           BJP        Fully Satisfied
# 16      BPL/Below ₹ 5,000      RJD           RJD     Fully Dissatisfied
# 18    ₹ 30,000 - ₹ 50,000   JAP(L)         JD(U)  Somewhat Dissatisfied
# ...                   ...      ...           ...                    ...
# 6579  ₹ 10,000 - ₹ 20,000      RJD         JD(U)     Fully Dissatisfied
# 6702  ₹ 10,000 - ₹ 20,000      BJP           BJP  Somewhat Dissatisfied
# 6720  ₹ 10,000 - ₹ 20,000      BJP           BJP     Somewhat Satisfied
# 6787  ₹ 20,000 - ₹ 30,000    JD(U)           BJP        Fully Satisfied
# 6851  ₹ 30,000 - ₹ 50,000      BJP           BJP        Fully Satisfied
#
#            MLA_satisfaction age age_group gender  assembly_no category  \
# 4           Fully Satisfied  22     18-25   Male          176       BC
# 8        Fully Dissatisfied  23     18-25   Male          181      Gen
# 14       Fully Dissatisfied  24     18-25   Male          199      Gen
# 16       Somewhat Satisfied  24     18-25   Male          194       BC
# 18       Fully Dissatisfied  23     18-25   Male          188       BC
# ...                     ...  ..       ...    ...          ...      ...
# 6579     Fully Dissatisfied  67       55+   Male          141       SC
# 6702     Fully Dissatisfied  68       55+   Male          146      Gen
# 6720        Fully Satisfied  76       55+   Male          168      Gen
# 6787        Fully Satisfied  60       55+   Male          144       SC
# 6851  Somewhat Dissatisfied  66       55+   Male          165      Gen
#
#         weight  day
# 4     0.333505   24
# 8     0.226477   24
# 14    0.226477   24
# 16    0.769738   24
# 18    0.040519   24
# ...        ...  ...
# 6579  5.308107   29
# 6702  0.710519   31
# 6720  1.535906   31
# 6787  4.741094    1
# 6851  0.300990    1
#
# [5947 rows x 16 columns]

# %%
data['age_group'].unique()
# Out:
# array(['18-25', '25-40', '40-55', '55+'], dtype=object)

# %% [markdown]
# # Question 5 - How many samples were collected for each age-group? Which age-group had the most samples?

# %%
data['age_group'].value_counts()
# Out:
# 25-40    3246
# 18-25    1969
# 40-55     624
# 55+       108
# Name: age_group, dtype: int64

# %% [markdown]
# # Question 6 - What proportion of the respondents had opted for the RJD party in both the Vote_Now and the Past_Vote questions?

# %%
data['Vote_Now'].unique()
# Out:
# array(['JD(U)', 'BJP', 'RJD', 'JAP(L)', 'Others', 'NOTA', 'BSP', 'RJJP',
#        'Plurals', 'AAP', 'INC', 'LJP', 'RLSP', 'HAM', 'Undecided', 'VIP',
#        'Left Front', 'AIMIM'], dtype=object)

# %%
data[(data['Vote_Now'] == 'RJD') & (data['Past_Vote'] == 'RJD')]
# Out:
#       response_id collection_date urban_rural          education  \
# 16             17       5-24-2017       Rural  Post - Graduation
# 38             39       5-24-2017       Urban           Graduate
# 47             48       5-24-2017       Urban           Graduate
# 85             86       5-24-2017       Rural          12th Pass
# 120           121       5-24-2017       Rural           Graduate
# ...           ...             ...         ...                ...
# 3012         3013       5-29-2017       Urban  Post - Graduation
# 4753         4754       5-26-2017       Rural  Post - Graduation
# 5493         5494       5-26-2017       Urban           Graduate
# 5687         5688       5-29-2017       Urban           Graduate
# 5830         5831       5-30-2017       Urban           Graduate
#
#                    income Vote_Now Past_Vote        CM_satisfaction  \
# 16      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# 38      BPL/Below ₹ 5,000      RJD       RJD              Can’t say
# 47      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# 85      BPL/Below ₹ 5,000      RJD       RJD     Fully Dissatisfied
# 120    ₹ 1,50,000 & above      RJD       RJD        Fully Satisfied
# ...                   ...      ...       ...                    ...
# 3012  ₹ 50,000 - ₹ 80,000      RJD       RJD  Somewhat Dissatisfied
# 4753  ₹ 30,000 - ₹ 50,000      RJD       RJD     Fully Dissatisfied
# 5493  ₹ 30,000 - ₹ 50,000      RJD       RJD     Fully Dissatisfied
# 5687  ₹ 10,000 - ₹ 20,000      RJD       RJD     Fully Dissatisfied
# 5830  ₹ 50,000 - ₹ 80,000      RJD       RJD  Somewhat Dissatisfied
#
#         MLA_satisfaction age age_group gender  assembly_no category  \
# 16    Somewhat Satisfied  24     18-25   Male          194       BC
# 38             Can’t say  22     18-25   Male          181       SC
# 47    Fully Dissatisfied  20     18-25   Male          172       BC
# 85    Somewhat Satisfied  22     18-25   Male          187       BC
# 120      Fully Satisfied  23     18-25   Male          187       BC
# ...                  ...  ..       ...    ...          ...      ...
# 3012  Somewhat Satisfied  56       55+   Male          214       BC
# 4753  Fully Dissatisfied  61       55+   Male           16       BC
# 5493  Fully Dissatisfied  61       55+   Male          156      Gen
# 5687  Somewhat Satisfied  62       55+   Male          156      EBC
# 5830  Fully Dissatisfied  59       55+   Male           48      Gen
#
#          weight  day
# 16     0.769738   24
# 38     1.596987   24
# 47     1.188838   24
# 85     0.586158   24
# 120    0.891022   24
# ...         ...  ...
# 3012   4.052635   29
# 4753   4.650280   26
# 5493   1.044473   26
# 5687  10.814150   29
# 5830   2.359308   30
#
# [695 rows x 16 columns]

# %% [markdown]
# # Question 7 - For each day of sample collection, determine the proportion of respondents who were fully satisfied with the performance of the CM. So if there were a total of 1000 samples on day 1 and 300 out of those said they were fully satisfied, then our answer for that day would be 0.3.

# %%
b =data['collection_date'].value_counts()
b
# Out:
# 5-24-2017    1306
# 5-25-2017     850
# 5-28-2017     662
# 5-27-2017     576
# 6-1-2017      530
# 5-29-2017     522
# 5-30-2017     516
# 5-26-2017     504
# 5-31-2017     481
# Name: collection_date, dtype: int64

# %%
data['CM_satisfaction'].unique()
# Out:
# array(['Fully Satisfied', 'Fully Dissatisfied', 'Somewhat Dissatisfied',
#        'Can’t say', 'Somewhat Satisfied'], dtype=object)

# %%
a= data[data['CM_satisfaction'] == 'Fully Satisfied']['collection_date'].value_counts()
print(a)
# Out:
# 5-24-2017    128
# 5-25-2017     83
# 5-28-2017     76
# 6-1-2017      66
# 5-29-2017     62
# 5-30-2017     60
# 5-31-2017     52
# 5-26-2017     48
# 5-27-2017     48
# Name: collection_date, dtype: int64

# %%
c = a/b * 100

# %%
print(c)
# Out:
# 5-24-2017     9.800919
# 5-25-2017     9.764706
# 5-26-2017     9.523810
# 5-27-2017     8.333333
# 5-28-2017    11.480363
# 5-29-2017    11.877395
# 5-30-2017    11.627907
# 5-31-2017    10.810811
# 6-1-2017     12.452830
# Name: collection_date, dtype: float64
